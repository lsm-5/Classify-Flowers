# %%
#hide
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()

# %%
#hide
from fastbook import *
from fastai.vision.widgets import *

# %%
#conectando com API do azure para buscar imagens
key = os.environ.get('AZURE_SEARCH_KEY', '1b4cc03c770d424089107f54293a8875')

# %%
search_images_bing
# Out:
# <function fastbook.search_images_bing>

# %%
#confirmando a busca por tulipas na API
def search_images_bing(key, term, max_images: int = 150, **kwargs):    
     params = {'q':term, 'count':max_images}
     headers = {"Ocp-Apim-Subscription-Key":"1b4cc03c770d424089107f54293a8875"}
     search_url = "https://api.bing.microsoft.com/v7.0/images/search"
     response = requests.get(search_url, headers=headers, params=params)
     response.raise_for_status()
     search_results = response.json()    
     return L(search_results['value'])

results = search_images_bing(key, 'tulip')
ims = results.attrgot('content_url')
len(ims)
# Out:
# 150

# %%
#organizando as categorias
flower_types = 'tulip','sunflower','orchid'
path = Path('flowers')

# %%
#para cada item do flower_types, vai criar uma caminho geral flowers seguido de sua categoria e então de suas imagens.
if not path.exists():
    path.mkdir()
    for o in flower_types:
        dest = (path/o)
        dest.mkdir(exist_ok=True)
        results = search_images_bing(key, f'{o} flower')
        download_images(dest, urls=results.attrgot('content_url'))

# %%
#verificando se o caminho ficou exatamente como descrito na célula anterior
fns = get_image_files(path)
fns
# Out:
# (#450) [Path('flowers/orchid/Image_48.jpg'),Path('flowers/orchid/Image_62.jpg'),Path('flowers/orchid/Image_23.jpg'),Path('flowers/orchid/Image_74.jpg'),Path('flowers/orchid/Image_89.jpg'),Path('flowers/orchid/Image_42.jpg'),Path('flowers/orchid/Image_148.jpg'),Path('flowers/orchid/Image_78.jpg'),Path('flowers/orchid/Image_92.jpg'),Path('flowers/orchid/Image_150.jpg')...]

# %%
#verificando se algum dos arquivos baixados estão corrompidos
failed = verify_images(fns)
failed
# Out:
# (#0) []

# %%
#remove as imagens corrompidas
failed.map(Path.unlink);

# %%
# Criando um dataloader bem detalhado, passando o detalhamento por parâmetro // Dataloader é a classe entendível pra ser treinada
# O primeiro item da tupla passada pelo parâmetro "blocks" diz que a primeira é a variável independente que no nosso caso são as imagens
# O segundo item da tupla passada pelo parâmetro "blocks" doz qie a segunda variável é dependente que no nosso caso são as categorias de flores
# O segundo parâmetro é o caminho onde estão as imagens
# O terceiro parâmetro diz a respeito do conjunto de validação e sua aleatóridade
# No quarto parâmetro o get_y é a variável dependente, daí passamos o parent_label, pois ele vai usar o nome das pastas como as categorias
# No quinto parâmetro colocamos nossas imagens no mesmo tamanho 64X64
flowers = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))
flowers

# %%
# !pip install bing-image-downloader
from bing_image_downloader import downloader

for q in ['tulip','sunflower','orchid']:
  downloader.download(q, limit=150, output_dir="flowers", adult_filter_off=True, force_replace=False, timeout=5)
# Out:
# Requirement already satisfied: bing-image-downloader in /usr/local/lib/python3.6/dist-packages (1.0.4)
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 150 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://northwestphotos.files.wordpress.com/2012/04/100_0198.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://www.photos-public-domain.com/wp-content/uploads/2012/04/pink-tulip-with-one-petal-open.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://img3.wikia.nocookie.net/__cb20080709190044/symbolism/images/8/86/Red_tulip-2529.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://cdn.shopify.com/s/files/1/1902/7917/products/Tulip-Princess-Irene-2017_x2000_crop_center.jpg?v=1571652790
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.hadeco.co.za/wp-content/uploads/2016/01/Tulip-Apeldoorn-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://3.bp.blogspot.com/-V8JMp5LHNbc/UybFxXNGprI/AAAAAAAAAbg/DhwDWZSzpNY/s1600/Tulip-Pictures-3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://cdn.shopify.com/s/files/1/1902/7917/products/Tulip-Pink-Impression-8_grande.jpg?v=1496076506
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://www.gardeningknowhow.com/wp-content/uploads/2008/07/tulips.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from https://rickholliday.files.wordpress.com/2012/08/tulip-and-daffodil.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from http://www.theflowersavenue.com/gallery/tulip/tulip_2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://gardenofeady.files.wordpress.com/2014/04/tulip.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://www.vanengelen.com/media/catalog/product/cache/1/thumbnail/0dc2d03fe217f8c83829496872af24a0/t/_/t_gudoshnik.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from https://cdn.shopify.com/s/files/1/1902/7917/products/Tulip-Purple-Rain-2017-7_x2000_crop_center.jpg?v=1496087450
# [%] File Downloaded !
#
# [%] Downloading Image #14 from https://images.homedepot-static.com/productImages/9d353662-bc52-44a4-b532-340715c4d30c/svn/van-bourgondien-flower-bulbs-89359-64_1000.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://www.johnscheepers.com/media/catalog/product/cache/1/thumbnail/0dc2d03fe217f8c83829496872af24a0/t/_/t_design_impression_4-w.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from http://outofmyshed.files.wordpress.com/2012/04/lily-flowered-burgundy-tulip-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from https://tuliptopgardens.files.wordpress.com/2012/06/0132.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #18 from https://mtv-main-assets.mountvernon.org/files/callouts/keizerskroon-tulip.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://secure.i.telegraph.co.uk/multimedia/archive/02899/tulipnegrita_2899511b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #20 from http://growingnicely.co.uk/wp-content/uploads/2016/08/Tulip-Virichic.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https://www.vanengelen.com/media/catalog/product/cache/1/thumbnail/0dc2d03fe217f8c83829496872af24a0/t/_/t_tom_pouce_a.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #22 from https://www.vanengelen.com/media/catalog/product/cache/1/thumbnail/0dc2d03fe217f8c83829496872af24a0/t/_/t_kingsblood_2-w.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #23 from https://blog.longfield-gardens.com/wp-content/uploads/2016/06/olympic-flame-tulip-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #24 from https://s3.eu-west-2.amazonaws.com/jparkers/1000/1017611_3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from https://upload.wikimedia.org/wikipedia/commons/e/ea/Tulipa_suaveolens_floriade_to_Canberra.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from https://bethwalshphotography.files.wordpress.com/2013/06/single-yellow-rose-tulip-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #27 from https://www.vanengelen.com/media/catalog/product/cache/1/thumbnail/0dc2d03fe217f8c83829496872af24a0/t/_/t_banja_luka_1_1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #28 from https://www.thefactsite.com/wp-content/uploads/2018/06/tulip-facts.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #29 from https://www.johnscheepers.com/media/catalog/product/cache/1/thumbnail/0dc2d03fe217f8c83829496872af24a0/t/u/tul_lily_mix_main.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from http://upload.wikimedia.org/wikipedia/commons/2/2b/Pink_Tulip.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #31 from https://pixfeeds.com/images/flowers/tulips/1280-155373443-tulip.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #32 from http://blog.longfield-gardens.com/wp-content/uploads/2015/08/Tulip_Pink_Impression_4__MG_6192.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #33 from https://www.vanengelen.com/media/catalog/product/cache/1/thumbnail/0dc2d03fe217f8c83829496872af24a0/t/_/t_rembrandt_mix_1-w.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #34 from https://cdn.shopify.com/s/files/1/1902/7917/products/Tulip-Orange-Princess-8_x2000_crop_center.jpg?v=1529959590
# [%] File Downloaded !
#
# [%] Downloading Image #35 from https://cdn.shopify.com/s/files/1/1902/7917/products/Tulip-Daydream_x2000_crop_center.jpg?v=1497106211
# [%] File Downloaded !
#
# [%] Downloading Image #36 from http://georgeweigel.net/wp-content/uploads/2010/01/tulip.barcelona.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #37 from https://www.longisland.com/site_media/images/article/1-Camps.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #38 from https://cdn.shopify.com/s/files/1/1902/7917/products/Tulip-Oscar-12_x2000_crop_center.jpg?v=1522846371
# [%] File Downloaded !
#
# [%] Downloading Image #39 from https://criticalfinancial.com/wp-content/uploads/2014/02/Tulipalooza.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #40 from https://tulipsinholland.com/wp-content/uploads/2015/09/tulips-in-holland-B115.png
# [%] File Downloaded !
#
# [%] Downloading Image #41 from http://1.bp.blogspot.com/-pQOjVrSerSc/UIDSllEbbyI/AAAAAAAADRQ/ruPuYf6FauM/s1600/tulip+flower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #42 from https://www.travelblissnow.com/wp-content/uploads/2017/05/tulip-cover3-1020x704.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #43 from https://www.torontobulkflowers.com/wp-content/uploads/2018/04/orange-tulips.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #44 from https://www.longfield-gardens.com/_ccLib/image/plants/DETA-191.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #45 from https://www.youtulip.eu/photos/tulpen/Lilac%20Love%20T.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #46 from http://www.theflowersavenue.com/gallery/tulip/tulip_1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #47 from https://ae01.alicdn.com/kf/HTB1ATNFnhTI8KJjSspiq6zM4FXao/Tulip-Flower-10pcs-lot-Pu-Mini-Tulip-Flower-Real-Touch-Flower-Bouquet-Artificial-Silk-Flowers-for.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #48 from https://www.carithers.com/images/pageMakerImages/Tulip211061674409.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #49 from https://pixfeeds.com/images/21/507800/1200-505946212-recreado-tulip-flowers.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #50 from http://3.bp.blogspot.com/-b5WF3Q81PzA/UIDSjwofcCI/AAAAAAAADRA/hy3nCgVh3iQ/s1600/Tulip+Flower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #51 from https://www.vanengelen.com/media/catalog/product/cache/1/thumbnail/0dc2d03fe217f8c83829496872af24a0/t/_/t_dordogne_1-w.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #52 from https://www.johnscheepers.com/media/catalog/product/cache/1/thumbnail/0dc2d03fe217f8c83829496872af24a0/t/_/t_world_s_favorite_1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #53 from https://pixfeeds.com/images/flowers/tulips/640-115932340-red-tulip.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #54 from https://cdn0.wideopencountry.com/wp-content/uploads/2019/04/Tulip-Field.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #55 from https://hddesktopwallpapers.in/wp-content/uploads/2015/09/tulip-field-flowers.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #56 from https://dutchvillage.com/images/Tulip-Time-Pink-Tulips.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #57 from http://hddesktopwallpapers.in/wp-content/uploads/2015/11/tulip-picture-pic.jpg
# [!] Issue getting: http://hddesktopwallpapers.in/wp-content/uploads/2015/11/tulip-picture-pic.jpg
# [!] Error:: HTTP Error 301: The HTTP server returned a redirect error that would lead to an infinite loop.
# The last 30x error message was:
# Moved Permanently
# [%] Downloading Image #57 from https://www.gee-tee.co.uk/media/3543/happy-generation.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #58 from https://www.naturehills.com/media/catalog/product/cache/35c1080e597d6a74b42d0d88ced836c1/t/u/tulipa-pink-impression-600x601.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #59 from http://cdn2.shopify.com/s/files/1/1902/7917/products/Tulip-Purple-Prince_grande.jpg?v=1496077633
# [%] File Downloaded !
#
# [%] Downloading Image #60 from http://www.desicomments.com/wp-content/uploads/Beautiful-Tulip-Flower.png
# [%] File Downloaded !
#
# [%] Downloading Image #61 from http://cdn.shopify.com/s/files/1/1419/7120/products/sqTulip_Copper_Image.DV_1.jpg?v=1535042782
# [%] File Downloaded !
#
# [%] Downloading Image #62 from https://www.vanengelen.com/media/catalog/product/cache/1/thumbnail/0dc2d03fe217f8c83829496872af24a0/t/u/tul_single_late_violet_beauty_extra.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #63 from http://3.bp.blogspot.com/-kcrUC4HXOl0/TzBZMuRKp5I/AAAAAAAAApA/IkPH5rsfVnw/s1600/red_tulip_after_a_rain_shower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #64 from http://www.palmers.co.nz/wp-content/uploads/2017/03/Tulip-PNG-Pic-1.png
# [%] File Downloaded !
#
# [%] Downloading Image #65 from https://cdn.webshopapp.com/shops/108044/files/293550525/tulipa-rainbow-parrot.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #66 from https://cdn.shopify.com/s/files/1/2048/8041/products/Tulips_Columbus_-4_768x.jpg?v=1569530229
# [%] File Downloaded !
#
# [%] Downloading Image #67 from https://www.johnscheepers.com/media/catalog/product/cache/1/thumbnail/0dc2d03fe217f8c83829496872af24a0/t/_/t_parade_3_.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #68 from https://blog.longfield-gardens.com/wp-content/uploads/2015/08/03_Tulipa_Black_Parrot.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #69 from http://blog.marianilandscape.com/wp-content/uploads/Liriodendron-tulipifera-Tulip-Tree.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #70 from https://cdn.webshopapp.com/shops/108044/files/252623540/tulipa-lilac-love.jpg
# [!] Issue getting: https://cdn.webshopapp.com/shops/108044/files/252623540/tulipa-lilac-love.jpg
# [!] Error:: HTTP Error 404: Not Found
# [%] Downloading Image #70 from https://www.dutchtuliptours.com/wp-content/uploads/2018/09/Tulip-fields-e1579464957540.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #71 from https://ngb.org/wp-content/uploads/2018/10/Tulip-Charming-Beauty-Longfield-Gardens-600x600.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #72 from http://hddesktopwallpapers.in/wp-content/uploads/2015/08/pink-tulip-flowers.jpg
# [!] Issue getting: http://hddesktopwallpapers.in/wp-content/uploads/2015/08/pink-tulip-flowers.jpg
# [!] Error:: HTTP Error 301: The HTTP server returned a redirect error that would lead to an infinite loop.
# The last 30x error message was:
# Moved Permanently
# [%] Downloading Image #72 from https://static.toiimg.com/photo/68577789/Tulip-garden.jpg?width=748&amp;resize=4
# [%] File Downloaded !
#
# [%] Downloading Image #73 from https://s3.eu-west-2.amazonaws.com/jparkers/1000/1015717.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #74 from https://www.johnscheepers.com/media/catalog/product/cache/1/thumbnail/0dc2d03fe217f8c83829496872af24a0/t/_/t_budlight_2-w.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #75 from http://tulipsinholland.com/wp-content/uploads/2015/09/TulipsInHolland.com-2.png
# [%] File Downloaded !
#
# [%] Downloading Image #76 from https://onceuponajrny.com/wp-content/uploads/2019/05/Exploring-the-Tulip-Fields-in-the-Netherlands-in-a-VW-Bus.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #77 from https://www.vanengelen.com/media/catalog/product/cache/1/thumbnail/0dc2d03fe217f8c83829496872af24a0/t/_/t_elegant_lady_1-w_1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #78 from https://q7i2y6d5.stackpathcdn.com/wp-content/uploads/2015/07/parrot-tulip-400x597.jpg
# [!] Issue getting: https://q7i2y6d5.stackpathcdn.com/wp-content/uploads/2015/07/parrot-tulip-400x597.jpg
# [!] Error:: hostname 'www.q7i2y6d5.stackpathcdn.com' doesn't match either of '*.ssl.hwcdn.net', 'ssl.hwcdn.net'
# [%] Downloading Image #78 from https://cdn.shopify.com/s/files/1/1902/7917/products/Tulip-Dream-Touch-3_x2000_crop_center.jpg?v=1497115261
# [%] File Downloaded !
#
# [%] Downloading Image #79 from http://www.photos-public-domain.com/wp-content/uploads/2012/04/orange-striped-or-variegated-tulip.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #80 from https://mikesgardentop5plants.files.wordpress.com/2013/03/tulipmangocharm-300x292.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #81 from http://www.pngall.com/wp-content/uploads/2016/05/Tulip-PNG-HD.png
# [%] File Downloaded !
#
# [%] Downloading Image #82 from https://cdn.webshopapp.com/shops/108044/files/183225635/tulipa-pink-size.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #83 from http://tulipsinholland.com/wp-content/uploads/2015/07/Pink-tulips.png
# [%] File Downloaded !
#
# [%] Downloading Image #84 from https://www.vanengelen.com/media/catalog/product/cache/1/thumbnail/0dc2d03fe217f8c83829496872af24a0/t/_/t_fringed_mix.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #85 from http://outofmyshed.files.wordpress.com/2012/04/irene-parrot-tulip.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #86 from https://georgeweigel.net/wp-content/uploads/2010/01/tulip.sweetheart.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #87 from http://tulipsinholland.com/wp-content/uploads/2015/09/tulips-in-holland-V1.png
# [%] File Downloaded !
#
# [%] Downloading Image #88 from https://jardindesigndotorg1.files.wordpress.com/2013/09/floralia-2013-026.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #89 from http://www.theflowersavenue.com/gallery/tulip/tulip_4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #90 from http://www.vanishingtattoo.com/tds/images/flowers/flowers_large/tulip_003.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #91 from http://www.flowermuse.com/media/catalog/product/cache/1/image/1200x1200/9df78eab33525d08d6e5fb8d27136e95/p/u/purple-parrot-tulip-mysterious-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #92 from https://img.crocdn.co.uk/images/products2/pl/20/00/03/59/pl2000035950.jpg?width=940&amp;height=940
# [%] File Downloaded !
#
# [%] Downloading Image #93 from https://www.nature-and-garden.com/wp-content/uploads/2018/10/tulip-planting.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #94 from https://jardindesigndotorg1.files.wordpress.com/2013/09/floralia-2013-024.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #95 from https://jooinn.com/images/tulip-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #96 from https://cdn.webshopapp.com/shops/108044/files/183225689/tulipa-pink-size.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #97 from https://www.whiteflowerfarm.com/mas_assets/cache/image/6/3/6/f/25455.Jpg
# [%] File Downloaded !
#
# [%] Downloading Image #98 from https://img.crocdn.co.uk/images/products2/pl/20/00/00/60/pl2000006007.jpg?width=940&amp;height=940
# [%] File Downloaded !
#
# [%] Downloading Image #99 from https://cdn.shopify.com/s/files/1/1902/7917/products/Tulip-Columbus-2019-4_x2000_crop_center.jpg?v=1551977760
# [%] File Downloaded !
#
# [%] Downloading Image #100 from https://cdn.shopify.com/s/files/1/1902/7917/products/Tulip-Mondial-8_x2000_crop_center.jpg?v=1497166401
# [%] File Downloaded !
#
# [%] Downloading Image #101 from https://sissinghurstcastle.files.wordpress.com/2015/05/tulip-elegant-lady.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #102 from https://nfs.unl.edu/images/wood-plant/Tulip Tree Bloom 3 2010.JPG
# [!] Issue getting: https://nfs.unl.edu/images/wood-plant/Tulip Tree Bloom 3 2010.JPG
# [!] Error:: URL can't contain control characters. '/images/wood-plant/Tulip Tree Bloom 3 2010.JPG' (found at least ' ')
# [%] Downloading Image #102 from https://www.yabibo.com/wp-content/uploads/2017/02/tulip-field-53104_1920.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #103 from http://hddesktopwallpapers.in/wp-content/uploads/2015/08/tulip-pictures.jpg
# [!] Issue getting: http://hddesktopwallpapers.in/wp-content/uploads/2015/08/tulip-pictures.jpg
# [!] Error:: HTTP Error 301: The HTTP server returned a redirect error that would lead to an infinite loop.
# The last 30x error message was:
# Moved Permanently
# [%] Downloading Image #103 from https://cdn.webshopapp.com/shops/108044/files/206464532/tulipa-amazing-parrot.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #104 from https://upload.wikimedia.org/wikipedia/commons/thumb/6/6f/Official_portrait_of_Tulip_Siddiq_crop_2.jpg/1200px-Official_portrait_of_Tulip_Siddiq_crop_2.jpg
# [Error]Invalid image, not saving https://upload.wikimedia.org/wikipedia/commons/thumb/6/6f/Official_portrait_of_Tulip_Siddiq_crop_2.jpg/1200px-Official_portrait_of_Tulip_Siddiq_crop_2.jpg
#
# [!] Issue getting: https://upload.wikimedia.org/wikipedia/commons/thumb/6/6f/Official_portrait_of_Tulip_Siddiq_crop_2.jpg/1200px-Official_portrait_of_Tulip_Siddiq_crop_2.jpg
# [!] Error:: No active exception to reraise
# [%] Downloading Image #104 from http://www.theflowersavenue.com/gallery/tulip/tulip_3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #105 from https://cdn.webshopapp.com/shops/108044/files/183254372/tulipa-exclusive-tulips.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #106 from http://www.cutekitchenindia.com/yahoo_site_admin/assets/images/tulip.235185702.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #107 from http://www.weekendnotes.com/im/000/04/victoria-melbourne-silvan-tesselaar-tulip-farm-tul.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #108 from https://www.boredart.com/wp-content/uploads/2014/10/Fascinating-Tulip-field-Pictures-Never-to-be-Missed-17.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #109 from https://www.getawaymavens.com/wp-content/uploads/2015/05/Closed-tulip-buds.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #110 from https://colegallery.files.wordpress.com/2014/01/tuliptown-tulip.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #111 from http://hddesktopwallpapers.in/wp-content/uploads/2015/08/beautiful-tulip-wallpaper.jpg
# [!] Issue getting: http://hddesktopwallpapers.in/wp-content/uploads/2015/08/beautiful-tulip-wallpaper.jpg
# [!] Error:: HTTP Error 301: The HTTP server returned a redirect error that would lead to an infinite loop.
# The last 30x error message was:
# Moved Permanently
# [%] Downloading Image #111 from https://www.homestratosphere.com/wp-content/uploads/2019/02/Tulip-fields-in-Netherlands-with-windmill-feb8.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #112 from http://www.photos-public-domain.com/wp-content/uploads/2012/04/open-yellow-tulip.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #113 from https://upload.wikimedia.org/wikipedia/commons/2/20/AlbanyNY_Tulip_Festival.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #114 from http://www.glencove-li.us/wp-content/uploads/2015/10/Pink-Tulip.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #115 from https://www.johnscheepers.com/media/catalog/product/cache/1/thumbnail/0dc2d03fe217f8c83829496872af24a0/t/_/t_temple_of_beauty_1-w.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #116 from https://static.webshopapp.com/shops/108044/files/051085562/tulipa-brownie.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #117 from https://suzlipman.files.wordpress.com/2010/04/tulip-apricot3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #118 from https://upload.wikimedia.org/wikipedia/commons/thumb/d/df/Unidentified_Tulip_Tulipa_Red_Flower_1536px.jpg/1200px-Unidentified_Tulip_Tulipa_Red_Flower_1536px.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #119 from https://www.vanengelen.com/media/catalog/product/cache/1/thumbnail/0dc2d03fe217f8c83829496872af24a0/t/_/t_blushing_beauty_1-w.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #120 from https://cdn.shopify.com/s/files/1/1902/7917/products/Tulip_Mango_Charm_6_x2000_crop_center.jpg?v=1581949544
# [%] File Downloaded !
#
# [%] Downloading Image #121 from http://3.bp.blogspot.com/-SUyCvmGxqBk/T5720u1ScvI/AAAAAAAAAQU/RFEwSb6ZWNI/s1600/DSC_1951.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #122 from https://cdn.shopify.com/s/files/1/2048/8041/products/Belicia_Floret_1024x1024.jpg?v=1535828141
# [%] File Downloaded !
#
# [%] Downloading Image #123 from https://cdn.shopify.com/s/files/1/1902/7917/products/Tulip-Salmon-Impression-8_x2000_crop_center.jpg?v=1519299450
# [%] File Downloaded !
#
# [%] Downloading Image #124 from https://visitcanby.com/wp-content/uploads/2017/12/Wooden-shoe-tulip-festival.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #125 from https://www.youtulip.eu/photos/tulpen/Dordogne T.jpg
# [!] Issue getting: https://www.youtulip.eu/photos/tulpen/Dordogne T.jpg
# [!] Error:: URL can't contain control characters. '/photos/tulpen/Dordogne T.jpg' (found at least ' ')
# [%] Downloading Image #125 from https://www.vanengelen.com/media/catalog/product/cache/1/thumbnail/0dc2d03fe217f8c83829496872af24a0/t/u/tul_parrot_apricot_parrot_main.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #126 from https://bonniegunkel.files.wordpress.com/2011/02/tulip-bouquet.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #127 from https://media.cntraveler.com/photos/5509ca9c481a91bb781a030b/master/w_1200,c_limit/this-weekend-in-woodburn-oregon-tulip.jpg?mbid=social_retweet
# [%] File Downloaded !
#
# [%] Downloading Image #128 from http://cdn.shopify.com/s/files/1/1902/7917/products/Tulip-Pink-Impression-2_grande.jpg?v=1496076506
# [%] File Downloaded !
#
# [%] Downloading Image #129 from https://cdn.webshopapp.com/shops/108044/files/55694884/tulipa-maureen.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #130 from http://cdn.shopify.com/s/files/1/1902/7917/products/Tulip-Monte-Carlo_grande.jpg?v=1497166531
# [%] File Downloaded !
#
# [%] Downloading Image #131 from https://jooinn.com/images/tulip-flower-9.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #132 from http://nomadicdecorator.com/wp-content/uploads/2013/02/orange-princess-tulip.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #133 from http://www.travelblissnow.com/wp-content/uploads/2016/05/Tulip-collaget.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #134 from http://agrasar.co/wp-content/uploads/2015/04/flowers-wallpapers-tulip-garden-wallpaper-wallpaper-36465.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #135 from https://www.whiteflowerfarm.com/mas_assets/cache/image/6/3/8/c/25484.Jpg
# [%] File Downloaded !
#
# [%] Downloading Image #136 from http://im.rediff.com/getahead/2013/dec/02tulip-joshi5.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #137 from http://images.dailyhive.com/20170313134142/tulip-festival.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #138 from https://images.fineartamerica.com/images-medium-large-5/tulip-painted-in-shades-of-pink-rona-black.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #139 from http://blogs.nybg.org/plant-talk/wp-content/uploads/2015/04/0415-Tulipa-Worlds-Favorite-1200x800.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #140 from https://travelswithjayedotco.files.wordpress.com/2013/09/dsc3570.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #141 from https://cdn.shopify.com/s/files/1/1902/7917/products/Tulip-Purple-Rain-2017-8_x2000_crop_center.jpg?v=1496087450
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #142 from https://northwestphotos.files.wordpress.com/2012/04/100_0198.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #143 from http://www.photos-public-domain.com/wp-content/uploads/2012/04/pink-tulip-with-one-petal-open.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #144 from http://img3.wikia.nocookie.net/__cb20080709190044/symbolism/images/8/86/Red_tulip-2529.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #145 from https://cdn.shopify.com/s/files/1/1902/7917/products/Tulip-Princess-Irene-2017_x2000_crop_center.jpg?v=1571652790
# [%] File Downloaded !
#
# [%] Downloading Image #146 from https://www.hadeco.co.za/wp-content/uploads/2016/01/Tulip-Apeldoorn-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #147 from http://3.bp.blogspot.com/-V8JMp5LHNbc/UybFxXNGprI/AAAAAAAAAbg/DhwDWZSzpNY/s1600/Tulip-Pictures-3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #148 from https://cdn.shopify.com/s/files/1/1902/7917/products/Tulip-Pink-Impression-8_grande.jpg?v=1496076506
# [%] File Downloaded !
#
# [%] Downloading Image #149 from https://www.gardeningknowhow.com/wp-content/uploads/2008/07/tulips.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #150 from https://rickholliday.files.wordpress.com/2012/08/tulip-and-daffodil.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 150 images.
#
# ===============================================
#
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 150 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://upload.wikimedia.org/wikipedia/commons/thumb/4/40/Sunflower_sky_backdrop.jpg/1200px-Sunflower_sky_backdrop.jpg
# [Error]Invalid image, not saving https://upload.wikimedia.org/wikipedia/commons/thumb/4/40/Sunflower_sky_backdrop.jpg/1200px-Sunflower_sky_backdrop.jpg
#
# [!] Issue getting: https://upload.wikimedia.org/wikipedia/commons/thumb/4/40/Sunflower_sky_backdrop.jpg/1200px-Sunflower_sky_backdrop.jpg
# [!] Error:: No active exception to reraise
# [%] Downloading Image #1 from https://upload.wikimedia.org/wikipedia/commons/a/a9/A_sunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.treasuredhavenfarm.com/images/Sunflower7.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.almanac.com/sites/default/files/image_nodes/sunflower-1627193_1920.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.lionsroar.com/wp-content/uploads/2017/08/sunflower-field.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.treasuredhavenfarm.com/images/Sunflower9.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://www.agriorbit.com/wp-content/uploads/2019/05/sunflower-3550693_1920-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from http://www.treasuredhavenfarm.com/images/Treasured_Haven_Farm_Sunflower_Fields_2014.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from http://cdn.shopify.com/s/files/1/2607/3582/products/sunflower-diamond-painting-5685535670361_1024x1024.jpg?v=1557307347
# [%] File Downloaded !
#
# [%] Downloading Image #9 from http://www.lovethegarden.com/sites/default/files/content/articles/UK_sunflower-head-closeup.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://chilliwacksunflowerfest.com/wp-content/uploads/2018/08/IMG_8538.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://tau0.files.wordpress.com/2013/05/sunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://www.agricol.co.za/wp-content/gallery/sunflower/AGSUN_01-min1.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from http://southeastagnet.com/wp-content/uploads/2017/08/Sunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from https://www.mrfothergills.com.au/media/catalog/product/cache/1/thumbnail/1080x1400/17f82f742ffe127f42dca9de82fb58b1/5/0/5058_sunflower_giant_russian_single_2_.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://www.dayliliesinaustralia.com.au/wp-content/uploads/2019/04/Sunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from http://wallsdesk.com/wp-content/uploads/2017/01/Sunflower-HD-Desktop.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #17 from https://cdn.shopify.com/s/files/1/0034/1917/7060/products/Sunflower-Sunspot-Flower-Annual-Mckenzie-Seeds_800x.jpg?v=1545082339
# [%] File Downloaded !
#
# [%] Downloading Image #18 from https://nurserynature.com/1362-large_default/sunflower-plant-seasonal-winter-flower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #19 from https://2.bp.blogspot.com/-Ah9bPXZw4Wk/V5UdlBegFFI/AAAAAAAAAUU/B5rWlS5rbWc0Ayochd_VHGUk3B_oTd5RACLcB/s1600/Sunflower%2Blooks%2Blike%2Bthe%2BSun%2Bbecoming%2Blike%2BJesus.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #20 from https://prairiecalifornian.com/wp-content/uploads/2014/09/Sunflower-Photo-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #21 from https://stevetabone.files.wordpress.com/2012/09/single-sunflower.jpg?w=1024
# [%] File Downloaded !
#
# [%] Downloading Image #22 from https://cosmosmagazine.com/wp-content/uploads/2020/03/191104-Sunflower-full-1440x810.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #23 from https://www.swallowtailgardenseeds.com/flowers/sunflowers/sunflower-procut-horizon.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #24 from http://4.bp.blogspot.com/-NB_KmZdxrUA/Tp1NGCQ1U6I/AAAAAAAADPY/FnvLVYuEgdU/s1600/sunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #25 from https://www.gardeningknowhow.com/wp-content/uploads/2007/08/annual-sunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #26 from http://agrodaily.com/wp-content/uploads/2015/10/sunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #27 from http://cdn.shopify.com/s/files/1/0011/2341/8172/products/FL3254-3_1024x1024.jpg?v=1523415433
# [%] File Downloaded !
#
# [%] Downloading Image #28 from https://hips.hearstapps.com/hmg-prod.s3.amazonaws.com/images/skyscraper-sunflower-types-1586794555.jpg?crop=1.00xw:0.834xh;0,0.0426xh&amp;resize=480:*
# [%] File Downloaded !
#
# [%] Downloading Image #29 from https://post.healthline.com/wp-content/uploads/2020/03/sunflower-field-flowers-1200x628-facebook-1200x628.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #30 from https://softsolder.files.wordpress.com/2015/09/img_5701-sunflower-with-bumblebee-detail.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #31 from https://gardentabs.com/wp-content/uploads/2020/06/Beautiful-sunflower-field-in-the-summer.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #32 from https://www.swallowtailgardenseeds.com/blog/images/sunny-smile-sunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #33 from http://www.gardenhealth.com/wp-content/uploads/2018/01/Sunflower-article-image-1024x1024px-300x300.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #34 from https://www.fs.fed.us/wildflowers/plant-of-the-week/images/ashysunflower/Helianthus_mollis_8B_lg.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #35 from http://bobber.discoverwisconsin.com/media/sunflowercloseup-1024x682.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #36 from https://3c1703fe8d.site.internapcdn.net/newman/gfx/news/hires/2016/1-howsunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #37 from https://cdn.shopify.com/s/files/1/2538/7580/products/Flower_Sunflower_Sault_MI_-9707_1200x1200.jpg?v=1536227012
# [%] File Downloaded !
#
# [%] Downloading Image #38 from https://www.wintersexpress.com/files/2019/08/IMG_4605.sunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #39 from https://stevetabone.files.wordpress.com/2012/09/sunflower-standing-tall-with-its-bud-family.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #40 from http://2.bp.blogspot.com/-dOipS8mrjnI/UHpwLFDYFjI/AAAAAAAACrU/vtmb3OfbLlI/s1600/sunflower-wallpaper.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #41 from https://www.stephensonpersonalcare.com/admin/resources/sunflower-field-4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #42 from https://www.jjlawnserviceinc.com/wp-content/uploads/2015/03/sunflower_mammothrussian.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #43 from http://lovelaughterandliteracy.com/wp-content/uploads/2016/10/sunflower-9-1024x683.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #44 from https://nature.mdc.mo.gov/sites/default/files/media/images/2010/04/common_sunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #45 from http://justfunfacts.com/wp-content/uploads/2015/10/sunflower-facts.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #46 from https://www.ftd.com/blog/content/uploads/2015/06/sunflower-record-height.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #47 from https://3.bp.blogspot.com/-hQM8_YvB9FU/UHpwNWWOfJI/AAAAAAAACrs/sgZ5cFfWEZw/s1600/sunflowers.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #48 from http://www.greenvillageflowers.com/wp-content/uploads/2014/05/Sunflower.png
# [%] File Downloaded !
#
# [%] Downloading Image #49 from http://www.questgarden.com/58/99/8/071205112306/images/2268Sunflower-Posters.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #50 from https://2.bp.blogspot.com/-sCIhzJbKCEQ/UHTq0nTUbXI/AAAAAAAAV0w/1ytxWcmAy5o/s1600/Orange_sunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #51 from http://cdn.shopify.com/s/files/1/0011/2341/8172/products/FL3262-2_1024x1024.jpg?v=1523415450
# [%] File Downloaded !
#
# [%] Downloading Image #52 from http://higgledygarden.com/wp-content/uploads/2015/01/Sunflower-Field.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #53 from https://d1nw62gticy6e9.cloudfront.net/uploads/Early-Black-Heart-F1-Sunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #54 from https://pageflutter.com/wp-content/uploads/2017/09/Sunshine-blogger_sunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #55 from http://www.gardenhealth.com/wp-content/uploads/2018/11/Sunflower_2.png
# [%] File Downloaded !
#
# [%] Downloading Image #56 from https://agrilifecdn.tamu.edu/texasrowcrops/files/2015/06/Blooming-Sunflower-Head-2014.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #57 from https://img.thrfun.com/img/084/482/sunflower_information_and_photos_l1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #58 from https://modernfarmer.com/wp-content/uploads/2015/07/sunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #59 from https://www.muralswallpaper.co.uk/app/uploads/sunflower-sunrise-photographic-floral-wallpaper-mural-Plain.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #60 from https://juliegreenart.files.wordpress.com/2015/01/sunflower5.jpg?w=740&amp;h=1160
# [%] File Downloaded !
#
# [%] Downloading Image #61 from https://upload.wikimedia.org/wikipedia/commons/0/08/Sunflower_oil_and_sunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #62 from http://dreamstop.com/wp-content/uploads/2016/09/sunflower-dreams.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #63 from https://content.thriveglobal.in/wp-content/uploads/sites/3/2019/12/sunflower-field-3620919_1920.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #64 from https://cdn.britannica.com/82/7082-050-566913BA/Field-sunflowers-farm-valley-Assiniboine-River-Manitoba.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #65 from https://www.treasuredhavenfarm.com/images/SUNFLOWER4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #66 from http://suttons.s3.amazonaws.com/p/FLSSUN32597_3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #67 from https://www.applewoodseed.com/wp-content/uploads/Prairie-Sunflower-HEPE-703.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #68 from https://3.bp.blogspot.com/-NfGqWgUsszY/UOW1DltDqYI/AAAAAAAAcf4/cKWzeMXxNBQ/s1600/Sunflower+20.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #69 from http://www.flowersociety.org/images/Essences/FES/sunflower-plant-large.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #70 from https://morningchores.com/wp-content/uploads/2020/04/mammoth-russian-sunflower-800x533.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #71 from http://cdn.shopify.com/s/files/1/1581/3697/products/Sun_MamGrey_grande.jpg?v=1537202041
# [%] File Downloaded !
#
# [%] Downloading Image #72 from https://tjsgardendotcom1.files.wordpress.com/2012/06/lemon-queen-variety-sunflower.jpg?w=840&amp;h=560
# [%] File Downloaded !
#
# [%] Downloading Image #73 from https://www.flowermeaning.com/flower-pics/Sunflower/Sunflower-3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #74 from https://upload.wikimedia.org/wikipedia/en/thumb/c/c5/Annual%26perennial_sunflowerheads.jpg/1920px-Annual%26perennial_sunflowerheads.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #75 from https://www.rareseeds.com/assets/1/14/DimLarge/Flower-Sunflower-Titan-A-P-Whaley-DSC02112.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #76 from https://www.scienceabc.com/wp-content/uploads/2015/09/Sunflower-Pollination.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #77 from https://www.seriouslyflowers.com/wp-content/uploads/2017/10/Large-Sunflower-600x433.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #78 from https://2.bp.blogspot.com/-k3muyoVJ8dM/UD0FuFpmmOI/AAAAAAAAAxs/mggcJPNZeJQ/s1600/Neglected+Sunflower+%2528Helianthus+neglectus%2529.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #79 from https://www.sunflowerselections.com/wp-content/uploads/2014/10/Sundance-Kid1W.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #80 from https://www.swallowtailgardenseeds.com/blog/images/sunflower-peach-passion.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #81 from https://neihtn.files.wordpress.com/2018/08/sunflower_0f1a2677_dxo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #82 from https://inanyevent.com.au/wp-content/uploads/2018/02/Sun-Flower-ebay.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #83 from https://1721181113.rsc.cdn77.org/data/images/full/25450/sunflower-facing-the-sun.png
# [%] File Downloaded !
#
# [%] Downloading Image #84 from http://www.southernexposure.com/images/large/flower-sunflower-silverleaf_LRG.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #85 from https://www.swallowtailgardenseeds.com/flowers/sunflowers/sunflower-solar-flash.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #86 from https://thehomesteadinghippy.com/wp-content/uploads/2014/01/sunflower-large.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #87 from https://neihtn.files.wordpress.com/2018/08/sunflower_0f1a2691_dxo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #88 from https://thegardeningcook.com/wp-content/uploads/2017/04/sunflower-colors.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #89 from https://thegraphicsfairy.com/wp-content/uploads/2019/06/sunflower-image-Vintage-GraphicsFairy.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #90 from http://genomics-entrepreneurship.sites.olt.ubc.ca/files/2013/01/sunflower-940x704.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #91 from https://advancecovercrops.com/wp-content/uploads/2019/06/sunflower-cover-crop-advance-cover-crops3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #92 from https://verenasphotography.files.wordpress.com/2015/08/singlesunflower-mod-edit.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #93 from http://botany.one/wp-content/uploads/2016/01/Sunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #94 from https://www.photos-public-domain.com/wp-content/uploads/2017/08/yellow-sunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #95 from https://www.kellogggarden.com/wp-content/uploads/2018/06/sunflower-garden.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #96 from http://cdn.shopify.com/s/files/1/1766/2959/products/Sunflower_Dwarf_Sunspot_bb385cf7-833b-4c93-bb98-85e173e6f52d_600x.jpg?v=1536538823
# [%] File Downloaded !
#
# [%] Downloading Image #97 from https://www.pixelstalk.net/wp-content/uploads/images1/Sunflower-Wallpapers-HD.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #98 from https://images.wallpaperscraft.com/image/sunflower_heart_bloom_125741_3840x2400.jpg
# [Error]Invalid image, not saving https://images.wallpaperscraft.com/image/sunflower_heart_bloom_125741_3840x2400.jpg
#
# [!] Issue getting: https://images.wallpaperscraft.com/image/sunflower_heart_bloom_125741_3840x2400.jpg
# [!] Error:: No active exception to reraise
# [%] Downloading Image #98 from https://www.botanicalinterests.com/images/popup/2027i_Sunflower-Lemon-Queen-ORG.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #99 from https://www.smmtc.org/plantpix/2013/common_sunflower6.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #100 from http://3.bp.blogspot.com/-Eb2JxULzpVA/UHpwKeDiADI/AAAAAAAACrM/C7u3wz12Wug/s1600/sunflower+imge.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #101 from https://www.eumundiroses.com/sites/4328/products/205334_dsc_1572_1_full.jpg?v=3c32462f18c99e4fa7e9c7bf25b8e9d8
# [%] File Downloaded !
#
# [%] Downloading Image #102 from https://fsi.colostate.edu/wp-content/uploads/2017/03/sunflower-1705752_1920.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #103 from https://images.fineartamerica.com/images-medium-large-5/cheerful-sunflower-with-bee-carol-groenen.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #104 from https://banner2.kisspng.com/20180404/ayw/kisspng-sunflower-seed-common-sunflower-nut-gluten-snack-sunflowers-5ac557fb5f1f15.5341774815228825553896.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #105 from http://darkroom.baltimoresun.com/wp-content/uploads/2012/09/darkroom-sunflower-p11-fox.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #106 from https://www.swallowtailgardenseeds.com/flowers/sunflowers/sunflower-procut-brilliance.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #107 from https://fibonacci.com/wp-content/uploads/2019/01/Sunflower-Fibonacci.png
# [%] File Downloaded !
#
# [%] Downloading Image #108 from http://www.kentontimes.com/wp-content/uploads/2018/07/Sunflower-fields.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #109 from https://www.groedibles.com/wp-content/uploads/2011/07/sunflower_1423839c.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #110 from https://cdn11.bigcommerce.com/s-03b40/images/stencil/1280x1280/products/1202/1245/00100dPORTRAIT_00100_BURST20180412091641047_COVER__28840.1523540205.jpg?c=2&amp;imbypass=on
# [!] Issue getting: https://cdn11.bigcommerce.com/s-03b40/images/stencil/1280x1280/products/1202/1245/00100dPORTRAIT_00100_BURST20180412091641047_COVER__28840.1523540205.jpg?c=2&amp;imbypass=on
# [!] Error:: HTTP Error 404: Not Found
# [%] Downloading Image #110 from http://fsi.colostate.edu/wp-content/uploads/2017/03/sunflower-1577371_1920.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #111 from https://cdn.massagemag.com/wordpress/wp-content/uploads/sunflower-closeup-AS_75241343.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #112 from http://biggsytravels.com/wp-content/uploads/2017/08/a-lone-hitchin-sunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #113 from https://www.mickeyshannon.com/photos/pastel-sunflower-sunset.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #114 from http://www.beautifulflowerpictures.com/blog/wp-content/uploads/2010/09/sunflower_2145.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #115 from https://d1nw62gticy6e9.cloudfront.net/uploads/Mammoth-Sunflower-Seeds.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #116 from https://fablesandflora.files.wordpress.com/2014/07/sunflower-petals.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #117 from http://www.hdwallpaperspulse.com/wp-content/uploads/2016/10/21/beautiful-sunflower-image-hd.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #118 from http://www.southernexposure.com/images/large/sunflower-evening-sun_LRG.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #119 from https://cdn.shopify.com/s/files/1/2048/8041/products/Sunflower_Ruby_Eclipse-0670_1024x1024.jpg?v=1546524812
# [%] File Downloaded !
#
# [%] Downloading Image #120 from https://www.kargs.net/wallpaper/images/sunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #121 from https://www.sunflowerselections.com/wp-content/uploads/2014/10/GoldRush2CW.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #122 from https://static.superiorwallpapers.com/images/lthumbs/2017-08/12424_One-single-sunflower-in-the-sunset-light-HD-wallpaper.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #123 from http://www.birdsandblooms.com/wp-content/uploads/2015/07/Marshas-Sunflower-Field-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #124 from https://www.phipps.conservatory.org/assets/images/as_blog_image/MWD_sunflower_florets.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #125 from https://advancecovercrops.com/wp-content/uploads/2019/06/sunflower-crop-advance-cover-crops1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #126 from https://www.edenbrothers.com/store/media/Seeds-Flowers/SFSUN135.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #127 from https://www.sunflowerselections.com/wp-content/uploads/2017/10/IMG_5968.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #128 from https://www.consignmenter.com/assets/product/decorative-sunflower--helianthus-30-seeds--free-shipping/orig/6864-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #129 from https://cdn11.bigcommerce.com/s-q83qdckkjh/images/stencil/1280x1280/products/672/4206/Skyscraper-SunflowerBC1__44846.1560882894.jpg?c=2?imbypass=on
# [%] File Downloaded !
#
# [%] Downloading Image #130 from https://4.bp.blogspot.com/-BZGoT86wBqU/T6NHvuWpcZI/AAAAAAAAAPs/oHH9otgd9uI/s1600/sunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #131 from https://www.mickeyshannon.com/photos/zoom/pilsen-sunflower-sunset.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #132 from http://darkroom.baltimoresun.com/wp-content/uploads/2012/09/BS-md-darkroom-sunflower-p3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #133 from http://thechocolateaddict.com/blog/wp-content/uploads/2014/03/chocolate-sunflower-robin-robins.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #134 from https://cdn.shopify.com/s/files/1/2954/2248/products/Sunflower-Autumn-Beauty-Flower-Annual-Ferry-Morse_1400x.jpg?v=1582919099
# [%] File Downloaded !
#
# [%] Downloading Image #135 from https://granville.ces.ncsu.edu/wp-content/uploads/2012/07/sunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #136 from https://gardeningsolutions.ifas.ufl.edu/images/plants/flowers/sunflower_annuus.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #137 from https://www.hdwallpapers.in/walls/high_quality_sunflower-normal.jpg
# [!] Issue getting: https://www.hdwallpapers.in/walls/high_quality_sunflower-normal.jpg
# [!] Error:: HTTP Error 503: Service Temporarily Unavailable
# [%] Downloading Image #137 from https://geeglenews.com/wp-content/uploads/2016/06/beautiful-sunflower-wallpapers-9.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #138 from https://www.chinatouradvisors.com/UpLoad/201412/million-sunflower-garden-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #139 from https://eastonfarmersmarket.com/wp-content/uploads/2019/08/sunflower-day-2019.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #140 from http://jackiejacobson.com/wp-content/uploads/2010/08/Sunflower-V.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #141 from http://hddesktopwallpapers.in/wp-content/uploads/2015/11/sunflower-pictures.jpg
# [!] Issue getting: http://hddesktopwallpapers.in/wp-content/uploads/2015/11/sunflower-pictures.jpg
# [!] Error:: HTTP Error 301: The HTTP server returned a redirect error that would lead to an infinite loop.
# The last 30x error message was:
# Moved Permanently
# [%] Downloading Image #141 from http://beautifulflowerpictures.com/wp-content/uploads/2014/05/bfp_sunflower_row.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #142 from http://www.sunflowerselections.com/wp-content/uploads/2014/10/Little-Tiger2W.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #143 from https://whiteseed.com/images/Goldy-Double-Sunflower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #144 from https://fiestaflowersaz.com/wp-content/uploads/2017/04/Sunflower-Garden-52.99-V-1111.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #145 from https://media.istockphoto.com/vectors/vector-sunflower-icon-vector-id1027650158
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ...
# [%] Downloading Image #52 from https://4.bp.blogspot.com/-j7lLMgEZDV4/TdcBaO7n36I/AAAAAAAAJKI/a_vUi08ok5s/s1600/orchid22011.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #53 from http://www.theorchidhobbyist.com/wp-content/uploads/2017/09/IMG_1313.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #54 from https://geartrench.com/wp-content/uploads/2020/03/Pink-Dendrobium-Orchid-Flower.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #55 from https://fourseasonsnursery.files.wordpress.com/2012/05/cymbidium-orchid21.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #56 from https://cdn.shopify.com/s/files/1/1334/4597/products/FSO037-OC-Fuchsia-Phalaenopsis-Orchid_2048x.jpg?v=1548263633
# [%] File Downloaded !
#
# [%] Downloading Image #57 from https://www.fijitimes.com/wp-content/uploads/2018/05/Dendrobium-Orchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #58 from http://hddesktopwallpapers.in/wp-content/uploads/2015/11/orchid-flower-hd-wallpapers.jpg
# [!] Issue getting: http://hddesktopwallpapers.in/wp-content/uploads/2015/11/orchid-flower-hd-wallpapers.jpg
# [!] Error:: HTTP Error 301: The HTTP server returned a redirect error that would lead to an infinite loop.
# The last 30x error message was:
# Moved Permanently
# [%] Downloading Image #58 from https://nittygrittydirtman.files.wordpress.com/2012/02/ground-orchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #59 from https://leggypeggy.files.wordpress.com/2015/04/white-pink-orchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #60 from http://teakdoor.com/Gallery/albums/userpics/10004/normal_Thai_orchid_2.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #61 from https://cdn.notonthehighstreet.com/system/product_images/images/001/047/136/original_moth-orchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #62 from http://blog.givingplants.com/wp-content/uploads/2013/06/miltonia-orchid-flowers.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #63 from http://insectstore.com/wp-content/uploads/2014/07/orchid-mantis-hymenopus-coronatus-nylph.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #64 from https://bloomd.com.au/wp-content/uploads/2018/08/Orchid-two.jpg
# [!] Issue getting: https://bloomd.com.au/wp-content/uploads/2018/08/Orchid-two.jpg
# [!] Error:: HTTP Error 404: Not Found
# [%] Downloading Image #64 from http://blogs.nybg.org/plant-talk/wp-content/uploads/2016/02/0216-slipper-orchids-800x1200.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #65 from https://cdn11.bigcommerce.com/s-828d5/images/stencil/1280x1280/products/261/1212/elegant-phaleanopsis-orchid-arrangement-2__35722.1569855752.jpg?c=2
# [%] File Downloaded !
#
# [%] Downloading Image #66 from http://flowerinfo.org/wp-content/gallery/orchid-flowers/orchid-flower-9.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #67 from https://spacegurrrl.wordpress.com/files/2008/05/purple-phalaenopsis-orchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #68 from http://1.bp.blogspot.com/-2uRQEBGxzL8/TWCOlsN_HeI/AAAAAAAAAG8/hjWQ7obhEkk/s1600/oncorchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #69 from http://www.rocketfarms.com/images/flowers/orchid-gallery/RF-Orchid-Gallery-(14).jpg
# [%] File Downloaded !
#
# [%] Downloading Image #70 from https://i.ytimg.com/vi/j17NYcH-k20/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #71 from http://wallpapersdsc.net/wp-content/uploads/2016/09/Orchid-Widescreen.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #72 from https://www.orchidweb.com/product_images/uploaded_images/phalaenopsis-orchid-plant.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #73 from https://1.bp.blogspot.com/-Nztr6eIh2Hw/T611Lj0mWlI/AAAAAAAABnE/I_2e8LdBuYw/s1600/orchid-white-gypsophila-grass-corsage-modern.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #74 from https://kiyanti2008.files.wordpress.com/2014/11/pink-phalaenopsis-orchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #75 from http://www.gardeningknowhow.com/wp-content/uploads/2014/05/terrestrial-orchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #76 from http://www.orchid-care-tips.com/image-files/miltoniopsis-hajime-ono.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #77 from https://cdn.gardenista.com/wp-content/uploads/2017/04/miltonia-orchid-mimi-giboin-143-1466x2199.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #78 from http://www.tesselaarflowers.com.au/wp-content/uploads/2013/03/phalaenopsis-orchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #79 from https://res.cloudinary.com/bloomnation/c_pad,d_vendor:global:catalog:product:image.png,f_auto,fl_preserve_transparency,q_auto/v1573700079/vendor/3759/catalog/product/2/0/20180727124433_file_5b5a6af1decc3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #80 from https://171dxwjpaqv2danpq11ixf2j-wpengine.netdna-ssl.com/wp-content/uploads/1999/05/moth-orchid-Phalaenopsis-species.jpg
# [Error]Invalid image, not saving https://171dxwjpaqv2danpq11ixf2j-wpengine.netdna-ssl.com/wp-content/uploads/1999/05/moth-orchid-Phalaenopsis-species.jpg
#
# [!] Issue getting: https://171dxwjpaqv2danpq11ixf2j-wpengine.netdna-ssl.com/wp-content/uploads/1999/05/moth-orchid-Phalaenopsis-species.jpg
# [!] Error:: No active exception to reraise
# [%] Downloading Image #80 from http://4.bp.blogspot.com/-eAKwk2abfGM/UnsWaMGBnXI/AAAAAAAAA_o/1mKcW0OZ2BQ/s1600/Green-Orchid-Flower-Wallpaper113711.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #81 from https://www.nybg.org/content/uploads/2017/04/NYBG_The_Orchid_Show_2017_01.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #82 from http://flowerstalk.ca/wp-system/uploads/2015/08/Haeckel_Orchidae.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #83 from https://www.morflora.com/wp-content/uploads/2019/03/Orchid-Flower-Meaning.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #84 from https://leggypeggy.files.wordpress.com/2015/04/green-pink-orchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #85 from https://4.bp.blogspot.com/-PNDByqiStF8/WgphoIIIckI/AAAAAAAABJw/kXiv2TYGDW0A-eK8hL_IqasfO-JSBoyawCEwYBhgL/s1600/3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #86 from http://1.bp.blogspot.com/-NXhcczJCzjk/TizsOnQjanI/AAAAAAAAAs4/Aw35Y7gpWC0/s1600/Bulbophyllum+alcicorne+Orchid+Flower+Picture+04.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #87 from https://curransflowers.imgix.net/images/item/2017-Orchid-Plants-Large-White5488-17032360928.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #88 from https://dallasgardendirt.files.wordpress.com/2015/06/purple-orchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #89 from http://dreamicus.com/data/orchid/orchid-01.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #90 from http://www.orchidspecies.co.uk/images/D/IMG_7254.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #91 from http://1.bp.blogspot.com/-zPKeXVajaIw/UdhO_4ZoS1I/AAAAAAAADHU/O_8VaxmpjfQ/s1600/orchid-cymbidium-plant-flowers.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #92 from https://www.justaddiceorchids.com/hubfs/Phalaenopsis%20Orchid%20Arrangement.jpg?t=1519656472353
# [%] File Downloaded !
#
# [%] Downloading Image #93 from http://orchidflowers.files.wordpress.com/2011/06/img_0003-red-orchid-cactus.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #94 from https://cdn.britannica.com/27/204727-050-1271EF08/Spider-orchid-bloom.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #95 from https://orchidflowers.files.wordpress.com/2011/06/tropical-orchids.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #96 from https://upload.wikimedia.org/wikipedia/commons/thumb/4/47/Orchid%2C_Barbados_%286756058581%29.jpg/854px-Orchid%2C_Barbados_%286756058581%29.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #97 from https://www.nybg.org/content/uploads/2017/04/NYBG_The_Orchid_Show_2017_02.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #98 from https://maximusonlinestores.com/wp-content/uploads/2020/01/orchid-flower-plant.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #99 from https://myrrh.co.nz/wp-content/uploads/2016/04/Orchid-e1494199891298.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #100 from http://2.bp.blogspot.com/-dT4dfm9hiN0/U68ONj_lBAI/AAAAAAAAAjE/hT2cv4StMlk/s1600/Bee+Orchid+No+2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #101 from http://orchidya.com/wp-content/uploads/2016/08/small-orchid-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #102 from http://2.bp.blogspot.com/-BsGvpQGDdGM/TjiaE6JYBEI/AAAAAAAAFFI/fuOJdka6S_k/s1600/white+orchid+wallpaper-3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #103 from http://www.tesselaarflowers.com.au/wp-content/uploads/2016/07/cymbidium_orchid_plant.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #104 from http://canadianorchidcongress.ca/wp-content/uploads/2015/09/453003.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #105 from http://1.bp.blogspot.com/-tsEnR3JxPEs/T6109lFB09I/AAAAAAAABm0/MSakAyLRTCI/s1600/white-orchid-gypsophila-bouquet-teardrop-modern.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #106 from https://www.ourhouseplants.com/imgs-gallery/mothorchidL8.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #107 from http://1.bp.blogspot.com/-We00M6zpkrE/TiFhQxpQGeI/AAAAAAAAApE/IUXhqT3swok/s1600/Vanda+Orchid+Flower+Picture+Purple+04.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #108 from https://media.treehugger.com/assets/images/2014/10/cluster-dracula-orchid.jpg.860x0_q70_crop-smart.jpg
# [!] Issue getting: https://media.treehugger.com/assets/images/2014/10/cluster-dracula-orchid.jpg.860x0_q70_crop-smart.jpg
# [!] Error:: <urlopen error [Errno -5] No address associated with hostname>
# [%] Downloading Image #108 from https://1.bp.blogspot.com/-jgAtBBsuhwo/TovWNSAhevI/AAAAAAAAA0Q/eBv9lMDxAws/s1600/orchids_black_orchid_040.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #109 from https://www.ftd.com/blog/content/uploads/2018/10/caring-for-orchids-how-to-grow-720x500.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #110 from https://res.cloudinary.com/bloomnation/c_pad,d_vendor:global:catalog:product:image.png,f_auto,fl_preserve_transparency,q_auto/v1553064541/vendor/2528/catalog/product/2/0/20190319114755_file_5c917fab1b595.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #111 from http://www.organicauthority.com/wp-content/uploads/2016/02/orchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #112 from http://images.fineartamerica.com/images-medium-large/purple-orchid-on-white-michael-waters.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #113 from https://4.bp.blogspot.com/-4qyUea1lTQA/TXmrSW-zacI/AAAAAAAAAds/Z-ghepcQbnU/s1600/yellow_cymbidium_orchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #114 from https://www.amthaiorchids.com/wp-content/uploads/2018/08/orchid_dendrobium_10001_Pattaya_red439_3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #115 from http://goorchids.s3.amazonaws.com/taxon-images-1000s1000/Orchidaceae/phaius-tankervilleae-fl-fkstarr.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #116 from http://clipartmag.com/images/orchid-flower-clipart-27.png
# [%] File Downloaded !
#
# [%] Downloading Image #117 from http://www.totalcomfortmedical.com/wp-content/uploads/2015/07/Phalaenopsis-moth-orchid-flower-e1437410680145.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #118 from https://upload.wikimedia.org/wikipedia/commons/0/02/Sun_Orchid_Bairne_Track.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #119 from http://factorydirectcraft.com/pimages/20140219144411-883187/green_cymbidium_orchid_flower.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #120 from https://www.morflora.com/wp-content/uploads/2019/03/jewel-orchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #121 from https://www.swallowtailgardenseeds.com/flowers/geraniums/geranium-orchid-blue.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #122 from http://aromasian.com/wp-content/uploads/2017/12/hibiscus-orchid-garden-7.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #123 from https://res.cloudinary.com/bloomnation/c_pad,d_vendor:global:catalog:product:image.png,f_auto,fl_preserve_transparency,q_auto/v1565760186/vendor/5245/catalog/product/2/0/20190813101959_file_5d53378f689fd_5d533847f1e2f.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #124 from http://www.modwedding.com/wp-content/uploads/orchid-wedding-bouquets-2-09212015-km.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #125 from http://www.wikihow.com/images/d/d9/Orchid-rescue-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #126 from https://onomea.com/wp-content/uploads/2019/05/Mini-Deltini-w-orchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #127 from https://images.fineartamerica.com/images-medium-large-5/2-phalaenopsis-orchid-named-be-tris-j-mccombie.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #128 from https://cdn.britannica.com/70/189570-050-5C358C8D/flowers-cymbidium-orchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #129 from http://www.gardenandgreenhouse.net/wp-content/uploads/2013/12/BlackOrchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #130 from https://www.hiresociety.com.au/wp-content/uploads/2016/10/Potted-Orchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #131 from http://bioweb.uwlax.edu/bio203/2011/peterson_alic/Pink_orchid[1].jpg
# [%] File Downloaded !
#
# [%] Downloading Image #132 from https://leggypeggy.files.wordpress.com/2015/04/yellow-rose-orchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #133 from https://2.bp.blogspot.com/-A_Z_7-v_N0I/XIskz8O59YI/AAAAAAAANm8/pYZccMitzk86etokhvJTo0Urc8fkfWcnQCLcBGAs/s1600/25846769158_a1fdb1fcd1_b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #134 from https://i0.wp.com/www.orchidspecies.com/orphotdir/phalamboinensis.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #135 from https://360view.hum3d.com/zoom/Flowers/Orchid_1000_0001.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #136 from http://goorchids.s3.amazonaws.com/taxon-images-1000s1000/Orchidaceae/epipactis-gigantea-fl-dmcadoo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #137 from http://2.bp.blogspot.com/-O__f0KWfslM/VJ_c37ypjlI/AAAAAAAAACg/KzmZ5xtIod8/s1600/orchid-mantis3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #138 from http://www.annarbor.com/FosterPhalaenopsisOrchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #139 from https://birdtherock.files.wordpress.com/2013/07/tallnortherngreenorchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #140 from https://smartgardenguide.com/wp-content/uploads/2019/02/how-to-care-for-a-dendrobium-nobile-orchid-23-768x1024.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #141 from https://botanicalgarden.berkeley.edu/wp-content/uploads/2014/12/orchid-300x300.png
# [%] File Downloaded !
#
# [%] Downloading Image #142 from https://3.bp.blogspot.com/-GY3Y0l0Q3eY/ToKLm1bXjrI/AAAAAAAAAKM/cOkCEBk1-u4/s1600/IMG_4821.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #143 from https://thmcf.files.wordpress.com/2013/07/bee-orchid-imc-3702.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #144 from https://lifestyle.co.za/wp-content/uploads/2018/04/Phalaenopsis-dendrobium-Moth-Orchid-3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #145 from https://meettheherbalist.files.wordpress.com/2013/04/purple-orchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #146 from https://mantodea2014.files.wordpress.com/2015/02/orchid_x_doritaenopsis_dorado_flower_2721px.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #147 from https://dallasgardendirt.files.wordpress.com/2015/06/yellow-orchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #148 from https://www.gardenmandy.com/wp-content/uploads/2019/09/Miltoniopsis-Orchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #149 from https://cdn.britannica.com/45/123445-050-37A360E8/Moth-orchid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #150 from https://www.flowerpower.com.au/wp-content/uploads/2018/12/Phalaenopsis-Orchid-P1060106-5.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 150 images.
#
# ===============================================

# %%
# Ainda precisamos dizer a fastai a fonte real de nossos dados - neste caso, o caminho onde as imagens podem ser encontradas.
dls = flowers.dataloaders(path)

# %%
# dando uma olhada nas imagens que obtivemos e passamos como conjunto de validação
dls.valid.show_batch(max_n=4, nrows=1)

# %%
# Redimensionando imagens para preencher com pretos, comprimi-las ou esticá-las
flowers = flowers.new(item_tfms=Resize(128, ResizeMethod.Squish))
dls = flowers.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
flowers = flowers.new(item_tfms=Resize(128, ResizeMethod.Pad, pad_mode='zeros'))
dls = flowers.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
# Redimensionando sem perder partes da imagem
flowers = flowers.new(item_tfms=RandomResizedCrop(128, min_scale=0.3))
dls = flowers.dataloaders(path)
dls.train.show_batch(max_n=4, nrows=1, unique=True)

# %%
# Aqui estamos gerando novas imagens apenas "brincando" com as mesmas imagens
flowers = flowers.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
dls = flowers.dataloaders(path)
dls.train.show_batch(max_n=8, nrows=2, unique=True)

# %%
# Aqui estamos modificando nossas imagens para gerar novas
flowers = flowers.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = flowers.dataloaders(path)

# %%
# Aqui treinamos nosso modelo
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.624855</td>
#       <td>0.895597</td>
#       <td>0.333333</td>
#       <td>01:33</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.293881</td>
#       <td>0.147614</td>
#       <td>0.044444</td>
#       <td>01:59</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.230481</td>
#       <td>0.033100</td>
#       <td>0.011111</td>
#       <td>02:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.167683</td>
#       <td>0.018091</td>
#       <td>0.000000</td>
#       <td>01:59</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.146645</td>
#       <td>0.018925</td>
#       <td>0.000000</td>
#       <td>01:59</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "

# %%
# Aqui vemos a matrix de confusão, utilizada para detectar como estão os nossos erros
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
# A seguir as imagens com maior probabilidade de erro
# previsão / real / perda /probabilidade
interp.plot_top_losses(5, nrows=1)

# %%
#Aqui ajudamos o nosso modelo a entender algumas imagens
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# VBox(children=(Dropdown(options=('orchid', 'sunflower', 'tulip'), value='orchid'), Dropdown(options=('Train', …

# %%
# A primeira linha comentada desvincula todas as imagens que colocamos delete na opção e a segunda move as imagens para as pastas q designamos
# Descomenta e treina novamente o modelo, e confira se a precisão melhora
# for idx in cleaner.delete(): cleaner.fns[idx].unlink()
# for idx,cat in cleaner.change(): shutil.move(str(cleaner.fns[idx]), path/cat)

# %%
# exportando nosso modelo
learn.export()

# %%
# confirmando se gerou o arquivo de exportação
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#1) [Path('export.pkl')]

# %%
# carregando o arquivo exportado
learn_inf = load_learner(path/'export.pkl')

# %%
# predizendo uma imagem aleatória
learn_inf.predict('/content/gdrive/My Drive/grizzly.jpg')

# %%
# observamos as categorias
learn_inf.dls.vocab
# Out:
# ['orchid', 'sunflower', 'tulip']

# %%
# Cria um botão de upload
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
# fakeamos a inserção de imagem com o botão
btn_upload = SimpleNamespace(data = ['/content/gdrive/My Drive/tulipa.jpg'])

# %%
# Pegamos a imagem que fizemos upload com o botão
img = PILImage.create(btn_upload.data[-1])

# %%
# Observamos a imagem que fizmos upload
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(img.to_thumb(128,128))
out_pl
# Out:
# Output()

# %%
# Aqui fazemos a previsão
pred,pred_idx,probs = learn_inf.predict(img)

# %%
# Aqui mostramos a previsão
lbl_pred = widgets.Label()
lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
lbl_pred
# Out:
# Label(value='Prediction: tulip; Probability: 0.9996')

# %%
# Aqui geramos um botão de classificação
btn_run = widgets.Button(description='Classify')
btn_run
# Out:
# Button(description='Classify', style=ButtonStyle())

# %%
# Aqui dizemos pra quando clicar no botão, qual função deve ser executada
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
# Retornando o botão para upload para a imagem
btn_upload = widgets.FileUpload()

# %%
# Criamos um espaço com tudo que criamos
VBox([widgets.Label('Select your flower!'), 
      btn_upload, btn_run, out_pl, lbl_pred])
# Out:
# VBox(children=(Label(value='Select your flower!'), FileUpload(value={'orquidea_phalaenopsis_pote_12_89207713_6…

# %%
# instalações necessárias caso não tenha feito para transformar em um web app
# !pip install voila
# !jupyter serverextension enable voila —sys-prefix

# %% [markdown]
# ### Deploying your app

# %% [markdown]
# For at least the initial prototype of your application, and for any hobby projects that you want to show off, you can easily host them for free. The best place and the best way to do this will vary over time, so check the [book's website](https://book.fast.ai/) for the most up-to-date recommendations. As we're writing this book in early 2020 the simplest (and free!) approach is to use [Binder](https://mybinder.org/). To publish your web app on Binder, you follow these steps:
#
# 1. Add your notebook to a [GitHub repository](http://github.com/).
# 2. Paste the URL of that repo into Binder's URL, as shown in <<deploy-binder>>.
# 3. Change the File dropdown to instead select URL.
# 4. In the "URL to open" field, enter `/voila/render/name.ipynb` (replacing `name` with the name of for your notebook).
# 5. Click the clickboard button at the bottom right to copyt the URL and paste it somewhere safe.
# 6. Click Launch.

# %% [markdown]
# <img alt="Deploying to Binder" width="800" caption="Deploying to Binder" id="deploy-binder" src="https://github.com/fastai/fastbook/blob/master/images/att_00001.png?raw=1">

# %% [markdown]
# The first time you do this, Binder will take around 5 minutes to build your site. Behind the scenes, it is finding a virtual machine that can run your app, allocating storage, collecting the files needed for Jupyter, for your notebook, and for presenting your notebook as a web application.
#
# Finally, once it has started the app running, it will navigate your browser to your new web app. You can share the URL you copied to allow others to access your app as well.
#
# For other (both free and paid) options for deploying your web app, be sure to take a look at the [book's website](https://book.fast.ai/).

# %% [markdown]
# You may well want to deploy your application onto mobile devices, or edge devices such as a Raspberry Pi. There are a lot of libraries and frameworks that allow you to integrate a model directly into a mobile application. However, these approaches tend to require a lot of extra steps and boilerplate, and do not always support all the PyTorch and fastai layers that your model might use. In addition, the work you do will depend on what kind of mobile devices you are targeting for deployment—you might need to do some work to run on iOS devices, different work to run on newer Android devices, different work for older Android devices, etc. Instead, we recommend wherever possible that you deploy the model itself to a server, and have your mobile or edge application connect to it as a web service.
#
# There are quite a few upsides to this approach. The initial installation is easier, because you only have to deploy a small GUI application, which connects to the server to do all the heavy lifting. More importantly perhaps, upgrades of that core logic can happen on your server, rather than needing to be distributed to all of your users. Your server will have a lot more memory and processing capacity than most edge devices, and it is far easier to scale those resources if your model becomes more demanding. The hardware that you will have on a server is also going to be more standard and more easily supported by fastai and PyTorch, so you don't have to compile your model into a different form.
#
# There are downsides too, of course. Your application will require a network connection, and there will be some latency each time the model is called. (It takes a while for a neural network model to run anyway, so this additional network latency may not make a big difference to your users in practice. In fact, since you can use better hardware on the server, the overall latency may even be less than if it were running locally!) Also, if your application uses sensitive data then your users may be concerned about an approach which sends that data to a remote server, so sometimes privacy considerations will mean that you need to run the model on the edge device (it may be possible to avoid this by having an *on-premise* server, such as inside a company's firewall). Managing the complexity and scaling the server can create additional overhead too, whereas if your model runs on the edge devices then each user is bringing their own compute resources, which leads to easier scaling with an increasing number of users (also known as *horizontal scaling*).

# %% [markdown]
# > A: I've had a chance to see up close how the mobile ML landscape is changing in my work. We offer an iPhone app that depends on computer vision, and for years we ran our own computer vision models in the cloud. This was the only way to do it then since those models needed significant memory and compute resources and took minutes to process inputs. This approach required building not only the models (fun!) but also the infrastructure to ensure a certain number of "compute worker machines" were absolutely always running (scary), that more machines would automatically come online if traffic increased, that there was stable storage for large inputs and outputs, that the iOS app could know and tell the user how their job was doing, etc. Nowadays Apple provides APIs for converting models to run efficiently on device and most iOS devices have dedicated ML hardware, so that's the strategy we use for our newer models. It's still not easy but in our case it's worth it, for a faster user experience and to worry less about servers. What works for you will depend, realistically, on the user experience you're trying to create and what you personally find is easy to do. If you really know how to run servers, do it. If you really know how to build native mobile apps, do that. There are many roads up the hill.
#
# Overall, we'd recommend using a simple CPU-based server approach where possible, for as long as you can get away with it. If you're lucky enough to have a very successful application, then you'll be able to justify the investment in more complex deployment approaches at that time.
#
# Congratulations, you have successfully built a deep learning model and deployed it! Now is a good time to take a pause and think about what could go wrong.
